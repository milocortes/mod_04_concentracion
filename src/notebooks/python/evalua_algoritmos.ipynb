# %% [markdown]
# # Cargamos las implementaciones de los algoritmos:
# <a href="https://colab.research.google.com/github/milocortes/mod_04_concentracion/blob/main/src/notebooks/python/evalua_algoritmos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
#
# * Genético con codificación binaria
# * PSO
# * DE

# %%
# !wget https://raw.githubusercontent.com/milocortes/mod_04_concentracion/main/src/notebooks/python/optimization_algo.py

# %%
from optimization_algo import genetico_binario, DE, PSO
import numpy as np

# %% [markdown]
# ## Función de prueba: Himmelblau

# %%
# Función Himmelblau 
def himmelblau(X):
    x,y = X
    return (x**2 + y -11)**2 + (x + y**2 -7)**2

# %%
# Ejecutamos el algoritmo genético binario

m = 100
n_variables = 2
i_sup_vec = [5, 5]
i_inf_vec = [-5, -5]
precision = 10
maxiter = 60
prob_c = 0.9

fitness_genetico, x_best_genetico = genetico_binario(himmelblau,m,n_variables,i_sup_vec,i_inf_vec,precision,maxiter,prob_c)
x_best_genetico
# Out:
# Evaluando poblacion inicial
# -----------------------------
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
#         Iteración 0
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
# -----------------------------
# -----------------------------
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
#         Iteración 1
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
# -----------------------------
# -----------------------------
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
#         Iteración 2
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
# -----------------------------
# -----------------------------
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
#         Iteración 3
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
# -----------------------------
# -----------------------------
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
#         Iteración 4
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
# -----------------------------
# -----------------------------
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
#         Iteración 5
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
# -----------------------------
# -----------------------------
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
# ...

# %%
# Ejecutamos el algoritmo DE
n_dim = 2               
lb = np.array([-5, -5]) 
ub = np.array([5, 5] )

maxiter = 60  

pc = 0.9 
pop_size = 100   


fitness_de, x_best_de = DE(himmelblau,pop_size,maxiter,pc,lb,ub,step_size = 0.8)

x_best_de
# Out:
# -----------------------------
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
#         Iteración 0
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
# -----------------------------
# -----------------------------
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
#         Iteración 1
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
# -----------------------------
# -----------------------------
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
#         Iteración 2
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
# -----------------------------
# -----------------------------
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
#         Iteración 3
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
# -----------------------------
# -----------------------------
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
#         Iteración 4
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
# -----------------------------
# -----------------------------
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
#         Iteración 5
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
# -----------------------------
# -----------------------------
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
#         Iteración 6
# ...

# %%
# Tamaño de la población
n = 100
# Número de variables
n_var = 2
l_bounds = np.array([-5,-5])
u_bounds = np.array([5,5])
maxiter = 60
# Social scaling parameter
α = 0.8
# Cognitive scaling parameter
β = 0.8
# velocity inertia
w = 0.5

fitness_pso, x_best_pso = PSO(himmelblau, n, maxiter, n_var, l_bounds, u_bounds, α, β, w)
x_best_pso
# Out:
# -----------------------------
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
#         Iteración 0
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
# -----------------------------
# -----------------------------
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
#         Iteración 1
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
# -----------------------------
# -----------------------------
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
#         Iteración 2
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
# -----------------------------
# -----------------------------
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
#         Iteración 3
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
# -----------------------------
# -----------------------------
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
#         Iteración 4
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
# -----------------------------
# -----------------------------
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
#         Iteración 5
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
# -----------------------------
# -----------------------------
# -%%%%%%%%%%%%%%%%%%%%%%%%%%%-
#         Iteración 6
# ...

# %%
# Comparamos el fitness de los algoritmos
import matplotlib.pyplot as plt 

plt.plot(range(maxiter), fitness_de, label ="DE")
plt.plot(range(maxiter), fitness_pso, label ="PSO")
plt.plot(range(maxiter), fitness_genetico, label ="Genético")

plt.legend()
plt.title("Comparación de algoritmos de optimización")
# Out:
# Text(0.5, 1.0, 'Comparación de algoritmos de optimización')

# %%
min_value = 100000
x_best = None
algo_best = None

for algo,x in zip(["Genético","DE","PSO"],[x_best_genetico,x_best_de,x_best_pso]):
    if himmelblau(x) < min_value:
        min_value = himmelblau(x)
        x_best = x
        algo_best = algo
print(f"El valor mínimo de la función es {min_value}\nEl mejor vector fue el del algoritmo {algo_best}\nx_best: {x_best}")
# Out:
# El valor mínimo de la función es 1.5589758067126176e-12
# El mejor vector fue el del algoritmo PSO
# x_best: [2.99999983 1.9999999 ]

# %% [markdown]
# # TAREA
#
# Para las siguientes funciones de prueba*:
#
# * Eggholder
# * Easom
# * Cross-in-tray
# * Ackley
# * Booth
# * Hölder table
#
# Utiliza los algoritmos Genético Binario, DE y PSO para encontrar el que tiene mejor desempeño para minimizar dichas funciones.
#
# Realice una visualización del desempeño de cada algoritmo para cada función.
#
# La tarea debe realizarse en equipo.
#
# El formato de entrega es un jupyter notebook.
#
# *Para la implementación de las funciones de prueba siga la liga de wikipedia vista en clase:
#
# https://en.wikipedia.org/wiki/Test_functions_for_optimization
